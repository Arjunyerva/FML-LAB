# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjunyerva/FML-LAB/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series([1,2,3,4])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
fruits = np.array(['apple','orange','mango','pear'])
series2 = pd.Series(fruits)
print(series2)
# Out:
# 0     apple
# 1    orange
# 2     mango
# 3      pear
# dtype: object

# %%
df1 = pd.DataFrame({
    "C1": [1, 4, 8, 7, 9],
    "C2": ['a', 'column', 'with', 'a', 'string'],
    "C3": [1.23, 23.5, 45.6, 32.1234, 89.453],
    "C4": [True, False, True, False, True]
})

# %%
print(df1)
# Out:
#    C1      C2       C3     C4
# 0   1       a   1.2300   True
# 1   4  column  23.5000  False
# 2   8    with  45.6000   True
# 3   7       a  32.1234  False
# 4   9  string  89.4530   True

# %%
mylist = [4, 8, 12, 16, 20]
df2 = pd.DataFrame(mylist)
print(df2)
# Out:
#     0
# 0   4
# 1   8
# 2  12
# 3  16
# 4  20

# %%
items = [['Phone', 2000], ['TV', 1500], ['Radio', 800]]
df3 = pd.DataFrame(items)
print(df3)
# Out:
#        0     1
# 0  Phone  2000
# 1     TV  1500
# 2  Radio   800

# %%
items = [['Phone', 2000], ['TV', 1500], ['Radio', 800]]
df4 = pd.DataFrame(items, columns=['Item', 'Price'], dtype=float)
print(df4)
# Out:
#     Item   Price
# 0  Phone  2000.0
# 1     TV  1500.0
# 2  Radio   800.0
# <ipython-input-9-0755eeebd180>:2: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df4 = pd.DataFrame(items, columns=['Item', 'Price'], dtype=float)

# %%
df4.describe()
# Out:
#              Price
# count     3.000000
# mean   1433.333333
# std     602.771377
# min     800.000000
# 25%    1150.000000
# 50%    1500.000000
# 75%    1750.000000
# max    2000.000000

# %%
data = pd.read_csv('cars.csv')
print(data)
# Out:
#      age  gender  miles   debt  income  sales
# 0     28       0     23      0    4099    620
# 1     26       0     27      0    2677   1792
# 2     30       1     58  41576    6215  27754
# 3     26       1     25  43172    7626  28256
# 4     20       1     17   6979    8071   4438
# ..   ...     ...    ...    ...     ...    ...
# 958   22       0     11   8778    9829   1593
# 959   19       1     23   4850    3470   4742
# 960   28       1     28   9312    2720  12771
# 961   50       0     29  51343    8713  28511
# 962   47       1     15   3735    6406   6104
#
# [963 rows x 6 columns]

# %%
data.head()
# Out:
#    age  gender  miles   debt  income  sales
# 0   28       0     23      0    4099    620
# 1   26       0     27      0    2677   1792
# 2   30       1     58  41576    6215  27754
# 3   26       1     25  43172    7626  28256
# 4   20       1     17   6979    8071   4438

# %%
data.tail()
# Out:
#      age  gender  miles   debt  income  sales
# 958   22       0     11   8778    9829   1593
# 959   19       1     23   4850    3470   4742
# 960   28       1     28   9312    2720  12771
# 961   50       0     29  51343    8713  28511
# 962   47       1     15   3735    6406   6104

# %%
data.head(3)
# Out:
#    age  gender  miles   debt  income  sales
# 0   28       0     23      0    4099    620
# 1   26       0     27      0    2677   1792
# 2   30       1     58  41576    6215  27754

# %%
data['age']
# Out:
# 0      28
# 1      26
# 2      30
# 3      26
# 4      20
#        ..
# 958    22
# 959    19
# 960    28
# 961    50
# 962    47
# Name: age, Length: 963, dtype: int64

# %%
data['gender']
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 958    0
# 959    1
# 960    1
# 961    0
# 962    1
# Name: gender, Length: 963, dtype: int64

# %%
print (data.loc[[0, 4, 7], ['age']])
# Out:
#    age
# 0   28
# 4   20
# 7   39

# %%
data.loc[:, ['age', 'gender']]
# Out:
#      age  gender
# 0     28       0
# 1     26       0
# 2     30       1
# 3     26       1
# 4     20       1
# ..   ...     ...
# 958   22       0
# 959   19       1
# 960   28       1
# 961   50       0
# 962   47       1
#
# [963 rows x 2 columns]

# %%
data.loc[:3, ['age', 'gender']]
# Out:
#    age  gender
# 0   28       0
# 1   26       0
# 2   30       1
# 3   26       1

# %%
d1 = {
    'subject_id': ['1', '2', '3', '4', '5'],
    'student_name': ['John', 'Emily', 'Kate', 'Joseph', 'Dennis']
}

d2 = {
    'subject_id': ['4', '5', '6', '7', '8'],
    'student_name': ['Brian', 'William', 'Lilian', 'Grace', 'Caleb']
}

df1 = pd.DataFrame(d1, columns=['subject_id', 'student_name'])
df2 = pd.DataFrame(d2, columns=['subject_id', 'student_name'])

# %%
df1
# Out:
#   subject_id student_name
# 0          1         John
# 1          2        Emily
# 2          3         Kate
# 3          4       Joseph
# 4          5       Dennis

# %%
df2
# Out:
#   subject_id student_name
# 0          4        Brian
# 1          5      William
# 2          6       Lilian
# 3          7        Grace
# 4          8        Caleb

# %%
pd.merge(df1, df2, on='subject_id')
# Out:
#   subject_id student_name_x student_name_y
# 0          4         Joseph          Brian
# 1          5         Dennis        William

# %%
raw = {
    'Name': ['John', 'John', 'Grace', 'Grace', 'Benjamin', 'Benjamin', 'Benjamin',
        'Benjamin', 'John', 'Alex', 'Alex', 'Alex'],
    'Position': [2, 1, 1, 4, 2, 4, 3, 1, 3, 2, 4, 3],
    'Year': [2009, 2010, 2009, 2010, 2010, 2010, 2011, 2012, 2011, 2013, 2013, 2012],
    'Marks':[408, 398, 422, 376, 401, 380, 396, 388, 356, 402, 368, 378]
}
df3 = pd.DataFrame(raw)

# %%
df3
# Out:
#         Name  Position  Year  Marks
# 0       John         2  2009    408
# 1       John         1  2010    398
# 2      Grace         1  2009    422
# 3      Grace         4  2010    376
# 4   Benjamin         2  2010    401
# 5   Benjamin         4  2010    380
# 6   Benjamin         3  2011    396
# 7   Benjamin         1  2012    388
# 8       John         3  2011    356
# 9       Alex         2  2013    402
# 10      Alex         4  2013    368
# 11      Alex         3  2012    378

# %%
group = df3.groupby('Year')

# %%
group

# %%
group.get_group(2010)
# Out:
#        Name  Position  Year  Marks
# 1      John         1  2010    398
# 3     Grace         4  2010    376
# 4  Benjamin         2  2010    401
# 5  Benjamin         4  2010    380

# %%
print(pd.concat([df1, df2]))
# Out:
#   subject_id student_name
# 0          1         John
# 1          2        Emily
# 2          3         Kate
# 3          4       Joseph
# 4          5       Dennis
# 0          4        Brian
# 1          5      William
# 2          6       Lilian
# 3          7        Grace
# 4          8        Caleb

# %%
pd.concat([df1, df2], axis=1)
# Out:
#   subject_id student_name subject_id student_name
# 0          1         John          4        Brian
# 1          2        Emily          5      William
# 2          3         Kate          6       Lilian
# 3          4       Joseph          7        Grace
# 4          5       Dennis          8        Caleb

# %%
data = {
    'Name': ['John', 'Alice', 'Joseph', 'Alex'],
    'English': [64, 78, 68, 58],
    'Maths': [76, 54, 72, 64]
}

df = pd.DataFrame(data)
df.describe()
# Out:
#          English      Maths
# count   4.000000   4.000000
# mean   67.000000  66.500000
# std     8.406347   9.712535
# min    58.000000  54.000000
# 25%    62.500000  61.500000
# 50%    66.000000  68.000000
# 75%    70.500000  73.000000
# max    78.000000  76.000000
